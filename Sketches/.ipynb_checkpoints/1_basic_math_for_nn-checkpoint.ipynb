# %%
# https://www.youtube.com/watch?v=Ny3LRl23dsM&list=PL4DAR-yJZysnIlH36t4fVP7i-pTsK81f9&index=3
# Базовая матрица для нейронных сетей

# Поэлементные операции
# Умножение матриц
# Размер матрицы
# Частные деривативы
# Полные деривативы

# %%
import torch

# %%
tensor1 = torch.rand([2, 3])

# %%
print(tensor1)
# Out:
# tensor([[0.3701, 0.5677, 0.0990],
#         [0.3196, 0.5485, 0.7351]])

# %%
import matplotlib.pyplot as plt
plt.imshow(torch.randn([224, 224, 3]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
tensor1.shape
# Out:
# torch.Size([2, 3])

# %%
tensor1
# Out:
# tensor([[0.3701, 0.5677, 0.0990],
#         [0.3196, 0.5485, 0.7351]])

# %%
tensor1[:, 0]
# Out:
# tensor([0.3701, 0.3196])

# %%
torch.pow(tensor1, 2)
# Out:
# tensor([[0.1370, 0.3223, 0.0098],
#         [0.1021, 0.3009, 0.5404]])

# %%
torch.pow(torch.tensor(-0.7306), 2)
# Out:
# tensor(0.5338)

# %%
torch.dot

torch.matmul

torch.mm
# Out:
# <function _VariableFunctionsClass.mm>

# %%
tensor2 = torch.randn([3, 2])

# %%
tensor1.shape
# Out:
# torch.Size([2, 3])

# %%
torch.mm(tensor1, tensor2)
# Out:
# tensor([[-0.6275,  0.6512],
#         [-0.9746,  1.0640]])

# %%
tensor1
# Out:
# tensor([[0.3701, 0.5677, 0.0990],
#         [0.3196, 0.5485, 0.7351]])

# %%
tensor2
# Out:
# tensor([[-0.3284,  0.1365],
#         [-0.7873,  0.9380],
#         [-0.5956,  0.6882]])

# %%
tensor1[0,:]
# Out:
# tensor([0.3701, 0.5677, 0.0990])

# %%
tensor2[:,0]
# Out:
# tensor([-0.3284, -0.7873, -0.5956])

# %%
torch.sum(tensor1[0,:] * tensor2[:,0])
# Out:
# tensor(-0.6275)
